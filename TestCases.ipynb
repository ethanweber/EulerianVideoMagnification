# %% [markdown]
# #### Test Cases
#
# Here we run test cases.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tqdm import tqdm
import os
import numpy as np
import a12 as vm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
VIDEO_NAME = "baby"
FRAMERATE = 30
FILENAME = f"Input/{VIDEO_NAME}.npy"
OUTPUT_PATH = f"Output/{VIDEO_NAME}"

video = np.load(FILENAME)
print("Loading video with shape: {}".format(video.shape))
# Out:
# Loading video with shape: (153, 277, 480, 3)

# %%
video.shape
# Out:
# (153, 277, 480, 3)

# %%
vm.testLowPass(video)
# Out:
# before -> after

# %%
vm.testTemporalIntensity(video)

# %%
# baby
VIDEO_NAME = "baby"
FRAMERATE = 30
FILENAME = f"Input/{VIDEO_NAME}.npy"
OUTPUT_PATH = f"Output/{VIDEO_NAME}"

video = np.load(FILENAME)
print("Loading video with shape: {}".format(video.shape))

vm.testYvsUV(video)
# Out:
# Loading video with shape: (153, 277, 480, 3)
# 100%|██████████| 153/153 [00:17<00:00,  8.91it/s]
# Saved images to Output/testYvsUV_Yonly/images
# Saved video to Output/testYvsUV_Yonly/images.mp4
# 100%|██████████| 153/153 [00:17<00:00,  8.86it/s]
# Saved images to Output/testYvsUV_UVonly/images
# Saved video to Output/testYvsUV_UVonly/images.mp4
# 100%|██████████| 153/153 [00:17<00:00,  8.89it/s]
# Saved images to Output/testYvsUV_both/images
# Saved video to Output/testYvsUV_both/images.mp4

# %%
vm.testDifferentOrders(video)
# Out:
# 100%|██████████| 153/153 [00:16<00:00,  9.10it/s]
# Saved images to Output/testDifferentOrders_2/images
# Saved video to Output/testDifferentOrders_2/images.mp4
# 100%|██████████| 153/153 [00:17<00:00,  8.96it/s]
# Saved images to Output/testDifferentOrders_4/images
# Saved video to Output/testDifferentOrders_4/images.mp4

# %%
vm.testGaussianvsButter(video)
